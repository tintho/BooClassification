# %%
GuessesOfTestData = ['Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Goblin',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Ghost',
  'Ghost',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Goblin',
  'Ghoul',
  'Ghoul',
  'Goblin',
  'Ghost',
  'Ghoul',
  'Ghost',
  'Ghost']

# %%
GuessesOfTestData
# Out:
# ['Ghoul',
#  'Goblin',
#  'Ghoul',
#  'Ghost',
#  'Ghost',
#  'Ghost',
#  'Ghoul',
#  'Ghoul',
#  'Goblin',
#  'Ghoul',
#  'Ghost',
#  'Ghoul',
#  'Goblin',
#  'Ghost',
#  'Ghoul',
#  'Ghost',
#  'Goblin',
#  'Ghost',
#  'Ghost',
#  'Ghoul',
#  'Ghoul',
#  'Goblin',
#  'Goblin',
#  'Goblin',
#  'Goblin',
#  'Goblin',
#  'Ghoul',
#  'Goblin',
#  'Ghoul',
#  'Ghoul',
#  'Goblin',
#  'Ghoul',
#  'Ghoul',
#  'Goblin',
#  'Goblin',
#  'Ghoul',
#  'Ghost',
#  'Goblin',
#  'Ghost',
#  'Goblin',
#  'Goblin',
#  'Ghoul',
#  'Goblin',
#  'Goblin',
#  'Goblin',
#  'Ghoul',
#  'Ghoul',
#  'Ghoul',
#  'Ghoul',
#  'Goblin',
#  'Goblin',
#  'Goblin',
#  'Ghost',
#  'Goblin',
#  'Goblin',
#  'Ghost',
#  'Goblin',
#  'Goblin',
#  'Ghoul',
#  'Ghost',
#  'Ghoul',
#  'Ghoul',
#  'Ghost',
#  'Goblin',
#  'Goblin',
#  'Ghoul',
#  'Ghoul',
#  'Goblin',
#  'Goblin',
#  'Ghoul',
#  'Goblin',
#  'Ghost',
#  'Ghoul',
#  'Ghoul',
#  'Goblin',
#  'Ghoul',
#  'Goblin',
#  'Goblin',
#  'Ghost',
#  'Goblin',
# ...
